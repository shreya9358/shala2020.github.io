# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya9358/shala2020.github.io/blob/master/DS_L3_20_April_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment - 3: Improving Graphs**
#
# ---
# Course website: [SHALA-2020](https://shala2020.github.io/)
#
# This assignment will get you familiarized with improving plots/graphs in Python.

# %% [markdown]
# ---
# ## Part 1 - Importing packages and loading data
# ---

# %% [markdown]
# ###Import the following libraries:
#
# * ```numpy``` with an alias name ```np```,
# * ```pandas``` with an alias name ```pd```,
# * ```matplotlib.pyplot``` with an alias name ```plt```, and
# * ```seaborn``` with an alias name ```sns```.
#
# *You are free to use any other popular libraries*.

# %%
# Load the libraries with their aliases 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Using the files ```train.csv``` and ```moviesData.csv```,  peform the following:
#
# * Load these file as ```pandas``` dataframes and store it in variables named ```train``` and ```movies``` respectively.
# * Print the first ten rows of ```train``` and last ten rows of ```movies```.

# %%
# Load train.csv and movies.csv 
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv(url_train)

# Print the first ten rows of train
train.head(10)
# Out:
#    Age  Attrition  ... YearsWithCurrManager  ID
# 0   41          1  ...                    5   0
# 1   49          0  ...                    7   1
# 2   37          1  ...                    0   2
# 3   33          0  ...                    0   3
# 4   27          0  ...                    2   4
# 5   32          0  ...                    6   5
# 6   59          0  ...                    0   6
# 7   30          0  ...                    0   7
# 8   38          0  ...                    8   8
# 9   36          0  ...                    7   9
#
# [10 rows x 34 columns]

# %%
# Load movies.csv
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url_movies)

# Print the last ten rows of movies 
movies.head(10)
# Out:
#    Unnamed: 0                   title  ...            actor4                actor5
# 0           1             Filly Brown  ...     Emilio Rivera   Joseph Julian Soria
# 1           2                The Dish  ...          Tom Long        Genevieve Mooy
# 2           3     Waiting for Guffman  ...       Eugene Levy           Bob Balaban
# 3           4    The Age of Innocence  ...  Richard E. Grant          Alec McCowen
# 4           5             Malevolence  ...     Heather Magee        Richard Glover
# 5           6             Old Partner  ...               NaN                   NaN
# 6           7               Lady Jane  ...   Jill Bennett II  Helena Bonham Carter
# 7           8            Mad Dog Time  ...      Ellen Barkin            Diane Lane
# 8           9  Beauty Is Embarrassing  ...   Jonathan Dayton        Cliff Benjamin
# 9          10    The Snowtown Murders  ...       Craig Coyne         Richard Green
#
# [10 rows x 31 columns]

# %% [markdown]
# ---
# ## Part 2 - Drawing correlation and heatmap
# ---

# %% [markdown]
# ### Using the correlation matrix, peform the following:
#
# * Find the correlation matrix for the ```movies```.
# * Draw a **heatmap** with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.
# * Create a ```mask``` to remove the duplicate values from the **heatmap**.

# %%
# Find out the correlation matrix 
print(movies.corr())
# Draw the heatmap 
moviesCorr = movies.corr()
plt.figure(figsize=(20,20))
sns.heatmap(moviesCorr, annot = True)
# Out:
#                 Unnamed: 0   runtime  ...  critics_score  audience_score
# Unnamed: 0        1.000000 -0.045146  ...       0.003937        0.012582
# runtime          -0.045146  1.000000  ...       0.169494        0.172237
# thtr_rel_year    -0.000639 -0.124754  ...      -0.096445       -0.062610
# thtr_rel_month    0.005468  0.215274  ...       0.047717        0.034901
# thtr_rel_day      0.046227  0.033998  ...       0.023837        0.033812
# dvd_rel_year     -0.000382 -0.088603  ...       0.009554       -0.073794
# dvd_rel_month    -0.015944 -0.036916  ...       0.041502        0.070543
# dvd_rel_day       0.024857  0.021001  ...      -0.024717        0.019294
# imdb_rating       0.027596  0.261153  ...       0.770764        0.865149
# imdb_num_votes    0.045508  0.342462  ...       0.200657        0.288328
# critics_score     0.003937  0.169494  ...       1.000000        0.710695
# audience_score    0.012582  0.172237  ...       0.710695        1.000000
#
# [12 rows x 12 columns]

# %%
# Creating a mask for removing duplicates 
to_be_masked = np.zeros(moviesCorr.shape, dtype=bool)
length = len(to_be_masked)
to_be_masked[np.triu_indices(length)] = True
plt.figure(figsize=(20,20))
sns.heatmap(moviesCorr, annot = True, mask=to_be_masked)

# %% [markdown]
# ---
# ## Part 3 - Drawing plots and customizing these
# ---

# %% [markdown]
# ### Using a histogram, peform the following:
#
# * Draw a histogram of all the numeric features in ```train```. Please note that this can be done in a single command.
#
# * Find out whether there is any redundant features in ```train```, which can be dropped while building a model.

# %%
# Draw a histogram 
#print(train.select_dtypes([np.number]).columns)
train.hist(train.select_dtypes([np.number]).columns)

# Find out the redundant features
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f65b886af60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b8514fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b84cf390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b8484668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b84349e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f65b8466d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b8426128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b83d8470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b83d84e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b833bba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f65b836ef28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b832b2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b82dd668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b828f9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b8244d68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f65b8204128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b81b34a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b81e9828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b819aba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b814cf28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f65b810a2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b80bc668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b80ed9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b809fd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b805f128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f65b800f4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b7fc2828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b8fcf828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b928d0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f65b8896b00>]],
#       dtype=object)

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Draw a scatter plot between between ```imdb_rating``` and ```audience_score```, and also fit a regression line.
# * Change the color of marker to red, size to 200, transparency to 0.3.

# %%
# Scatter plot to fit the regression line 
 sns.regplot(data = movies, x = 'imdb_rating', y='audience_score', scatter= True)

# %%
# Change marker of the scatter plot
plt.scatter(data=movies,x='imdb_rating', y = 'audience_score', c='Orange', s=200,alpha=0.2)
#plt.show()

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw a scatter plot between between ```petal_length``` and ```petal_width``` and color it according to the ```species```.
# * Change the size of marker to 100 and place the legend in ```lower right```.

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
# Use the 'hue' argument to provide a factor variable
sns.scatterplot(data=df,x='petal_length', y='petal_width',hue='species')
 
# Move the legend to an empty part of the plot
sns.scatterplot(x='petal_length', y='petal_width',data=df,s=50 )
plt.legend(loc='lower right')

# %% [markdown]
# ---
# ## Part 4 - Density Plots
# ---

# %% [markdown]
# ### Using density plots, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots for all the features ```sepal_width```, ```sepal_length```, ```petal_width```, and ```petal_length```. You can required to use subplots for plotting all the density plots.
# * Try drawing a [CDF](https://en.wikipedia.org/wiki/Cumulative_distribution_function) of these features. There is a [blog on medium](https://medium.com/@rishav.jnit/exploratory-data-analysis-eda-on-iris-dataset-using-python-cadd850c1fc6) on how to plot CDF. It will be covered in tutorial.

# %%
# library and dataset 
df = sns.load_dataset('iris')
iris_density=sns.kdeplot(df['sepal_width'], shade=True)
iris_density=sns.kdeplot(df['sepal_length'],shade=True)
iris_density=sns.kdeplot(df['petal_width'],shade=True)
iris_density=sns.kdeplot(df['sepal_length'],shade=True)


counts, bin_edges = np.histogram(df['sepal_length'], bins=30, density = True)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], cdf)

# %% [markdown]
# ### Using violin plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots of ```species``` versus ```sepal_length```.
# * Assign each group a color like
#
#     * versicolor - green,
#     * setosa - blue,
#     * virginica - m

# %%
# Draw the normal violin plots 

sns.violinplot(data=df,x='species',y='sepal_length')

# %%
# Change the color of each group 

palette = {"versicolor": "g", "setosa": "b", "virginica":"m"}
sns.violinplot(data=df,x='species',y='sepal_length',palette=palette)
